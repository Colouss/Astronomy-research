# %%
#estimating pi
import random
import matplotlib.pyplot as plt
#call the necessary arrays and counters
pointin = 0
totalpoint = 0
inx = []
iny = []
outx = []
outy = []
radius = 3 #The radius of the circle, as well as half the square length
n = 10000 # the number of sampled points we want
for i in range(n):
    #Sample a random x and y value within the constraints of the square
    x = random.uniform(-radius, radius)
    y = random.uniform(-radius, radius)
    r = (x**2 + y**2) #calculate the radius of the circle that the randomly regenerated point is on
    if r <= radius**2: #if the radius is smaller or equal than the actual radius,it is within the circle
        inx.append(x) #add the points into the in(side) x and in(side) y arrays
        iny.append(y)
        pointin += 1
    else: #if not, it is outside the circle
        outx.append(x) #add the points into the out(side) x and out(side) y arrays
        outy.append(y)
    totalpoint = totalpoint + 1
pi = 4*(pointin/totalpoint) #calculate pi by tallying up how many points are inside the circle with respect to how many are outside
#plot the samples
plt.figure()
plt.scatter(inx, iny, color='blue', label='Inside Circle')
plt.scatter(outx, outy, color='red', label='Outside Circle')
plt.title('Monte Carlo Estimation of Pi')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.axis('equal')
plt.show()
#show the result of the estimate
print("Estimated value of pi:", pi)
# Out:
# Estimated value of pi: 3.1532

# %%
#estimating pi, but changed so that it's easier to manually input the radius and the number of points to test
import random
import matplotlib.pyplot as plt
#call the necessary arrays and counters
inx = []
iny = []
outx = []
outy = []
def estimatepi(radius, n): #program takes in the radius, and the number of sampled points we want
    pointin = 0
    totalpoint = 0
    for i in range(n):
        #Sample a random x and y value within the constraints of the square
        x = random.uniform(-radius, radius)
        y = random.uniform(-radius, radius)
        r = (x**2 + y**2) #calculate the radius of the circle that the randomly regenerated point is on
        if r <= radius**2: #if the radius is smaller or equal than the actual radius,it is within the circle
            inx.append(x) #add the points into the in(side) x and in(side) y arrays
            iny.append(y)
            pointin += 1
        else: #if not, it is outside the circle
            outx.append(x) #add the points into the out(side) x and out(side) y arrays
            outy.append(y)
        totalpoint = totalpoint+1
    pi = 4*(pointin/totalpoint) #calculate pi by tallying up how many points are inside the circle with respect to how many are outside
    return pi, inx, iny, outx, outy #the subprogram outputs the estimated pi, as well as the coordinates of all the xs and ys
pi, inx, iny, outx, ouy = estimatepi(5, 10000)
#plot the samples
plt.figure()
plt.scatter(inx, iny, color='blue', label='Inside Circle')
plt.scatter(outx, outy, color='red', label='Outside Circle')
plt.title('Monte Carlo Estimation of Pi')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.axis('equal')
plt.show()
#show the result of the estimate
print("Estimated value of pi:", pi)
# Out:
# Estimated value of pi: 3.1384

# %%
#estimating pi, with a graph that shows how the estimation converges to near pi
import random
import matplotlib.pyplot as plt
import math
#call the necessary arrays and counters
inx = []
iny = []
outx = []
outy = []
iteration = []
estimation = []
def estimatepi(radius, n): #program takes in the radius, and the number of sampled points we want
    pointin = 0
    totalpoint = 0
    for i in range(n):
        #Sample a random x and y value within the constraints of the square
        x = random.uniform(-radius, radius)
        y = random.uniform(-radius, radius)
        r = (x**2 + y**2) #calculate the radius of the circle that the randomly regenerated point is on
        if r <= radius**2: #if the radius is smaller or equal than the actual radius,it is within the circle
            inx.append(x) #add the points into the in(side) x and in(side) y arrays
            iny.append(y)
            pointin += 1
        else: #if not, it is outside the circle
            outx.append(x) #add the points into the out(side) x and out(side) y arrays
            outy.append(y)
        totalpoint = totalpoint + 1
        pi = 4*(pointin/totalpoint) #calculate pi by tallying up how many points are inside the circle with respect to how many are outside
        iteration.append(i) #append the iteration and the current estimation of pi into an array
        estimation.append(pi)
    return pi, inx, iny, outx, outy #the subprogram outputs the estimated pi, as well as the coordinates of all the xs and ys
pi, inx, iny, outx, ouy = estimatepi(1, 10000)
#plot the samples
plt.figure()
plt.scatter(inx, iny, color='blue', label='Inside Circle')
plt.scatter(outx, outy, color='red', label='Outside Circle')
plt.title('Monte Carlo Estimation of Pi')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.axis('equal')
plt.show()
#plot out the convergence of the iteration vs the estimate
print("Estimated value of pi:", pi)
plt.plot(iteration, estimation)
plt.axhline(y=3.14, color='r', linestyle='--')
plt.xlabel('Number of Points Tested')
plt.ylabel('Estimated Value of Pi')
plt.title('Convergence of Estimated Pi')
plt.show()
# Out:
# Estimated value of pi: 3.1492

# %%
#estimating pi, with a graph that shows how the estimation converges to near pi
import random
import matplotlib.pyplot as plt
import math
import numpy as np
#call the necessary arrays and counters
inx = []
iny = []
outx = []
outy = []
iteration = []
estimation = []
def estimatepi(radius, n): #program takes in the radius, and the number of sampled points we want
    pointin = 0
    totalpoint = 0
    for i in range(n):
        #Sample a random x and y value within the constraints of the square
        x = random.uniform(-radius, radius)
        y = random.uniform(-radius, radius)
        r = (x**2 + y**2) #calculate the radius of the circle that the randomly regenerated point is on
        if r <= radius**2: #if the radius is smaller or equal than the actual radius,it is within the circle
            inx.append(x) #add the points into the in(side) x and in(side) y arrays
            iny.append(y)
            pointin += 1
        else: #if not, it is outside the circle
            outx.append(x) #add the points into the out(side) x and out(side) y arrays
            outy.append(y)
        totalpoint = totalpoint + 1
        pi = 4*(pointin/totalpoint) #calculate pi by tallying up how many points are inside the circle with respect to how many are outside
        iteration.append(i) #append the iteration and the current estimation of pi into an array
        estimation.append(pi)
    return pi, inx, iny, outx, outy #the subprogram outputs the estimated pi, as well as the coordinates of all the xs and ys
n = 10000
pi, inx, iny, outx, ouy = estimatepi(1, n)
#Calculates the variance and standard error of the function
variance = np.var(estimation)
SE = variance / math.sqrt(n)
#plot the samples
plt.figure()
plt.scatter(inx, iny, color='blue', label='Inside Circle')
plt.scatter(outx, outy, color='red', label='Outside Circle')
plt.title('Monte Carlo Estimation of Pi')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.axis('equal')
plt.show()
#plot out the convergence of the iteration vs the estimate
print("Estimated value of pi:", pi)
plt.plot(iteration, estimation)
plt.axhline(y=3.14, color='r', linestyle='--')
plt.xlabel('Number of Points Tested')
plt.ylabel('Estimated Value of Pi')
plt.title('Convergence of Estimated Pi')
plt.show()
print("The variance of the estimation is:", variance)
print("The standard error of the estimation is:", SE)
# Out:
# Estimated value of pi: 3.134
# The variance of the estimation is: 0.0010097323980482146
# The standard error of the estimation is: 1.0097323980482146e-05
